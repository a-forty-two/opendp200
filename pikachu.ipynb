# %%
# first => i will try to access data lake without keyvault

dbutils.fs.mount(
  source='wasbs://bricky@jackfruit.blob.core.windows.net',
  mount_point='/mnt/lake')
# error expected-> because LAKE is NOT PUBLIC
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">ExecutionError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-892088927321726&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      3</span> dbutils.fs.mount(
# ...

# %%
dbutils.fs.mount(
  source='wasbs://bricky@jackfruit.blob.core.windows.net',
  mount_point='/mnt/lake', 
  extra_configs={'fs.azure.account.key.jackfruit.blob.core.windows.net':dbutils.secrets.get(scope='genghiskahn',key='bugsbunny')})

# KEY-> file system reference that dev should know about the datastore
# key-> Azure-> fs.azure.auth.rest_of_blob_url 
# AUTH: short term (SHARED ACCESS SIGNATURE), or LONG TERM(ACCOUNT.KEY)
# SAS-> fs.azure.sas
# Account.key -> fs.azure.account.key 
# key-> fs.azure.account.key.rest_of_blob_url
# my case-> fs.azure.account.key.jackfruit.blob.core.windows.net
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[1]: True</div>

# %%
data = spark.read.csv('/mnt/lake/dummy.csv', header=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+---+
#       name|age|
# +----------+---+
#  shaktiman|  8|
# donaldduck|  5|
#  daffyduck|  2|
# +----------+---+
#
# </div>

# %%
y = data.select('age')
y.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+
# age|
# +---+
#   8|
#   5|
#   2|
# +---+
#
# </div>
